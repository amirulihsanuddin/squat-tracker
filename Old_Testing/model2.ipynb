# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
# Out:
# WARNING:tensorflow:From C:\Users\eddcr\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load landmark data from CSV
df = pd.read_csv('good-bend-cvin-cvout-nohands-rmv.csv')

# Assuming your CSV has columns for coordinates and labels
landmarks = df.drop(columns=['class']).values
labels = df['class'].values

# Convert string labels to integer labels
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# Convert labels to one-hot encoding
labels = tf.keras.utils.to_categorical(labels, num_classes=4)

# Define parameters
num_landmarks = landmarks.shape[1]  # Assuming the number of landmarks is fixed
batch_size = 1
epochs = 50

# Create a model for landmark-based classification
model = models.Sequential()
model.add(layers.Dense(256, activation='relu', input_shape=(num_landmarks,)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))  # Assuming 7 classes

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Data splitting (you may need to adjust this based on your dataset)
from sklearn.model_selection import train_test_split
landmarks_train, landmarks_test, labels_train, labels_test = train_test_split(landmarks, labels, test_size=0.2, random_state=42)

# Train the model
history = model.fit(landmarks_train, labels_train,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(landmarks_test, labels_test))

# Evaluate the model
accuracy = model.evaluate(landmarks_test, labels_test)
print(f'Test Accuracy: {accuracy[1]}')

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss')
plt.xlabel('Epoch')
plt.show()

# %%
# Load landmark data from CSV
df = pd.read_csv('good-bend-cvin-cvout-nohands-rmv.csv')

# Assuming your CSV has columns for coordinates and labels
landmarks = df.drop(columns=['class']).values
labels = df['class'].values

# Convert string labels to integer labels
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# Convert labels to one-hot encoding
labels = tf.keras.utils.to_categorical(labels, num_classes=4)

# Define parameters
num_landmarks = landmarks.shape[1]  # Assuming the number of landmarks is fixed
batch_size = 2
epochs = 50

# Create a model for landmark-based classification
model = models.Sequential()
model.add(layers.Dense(256, activation='relu', input_shape=(num_landmarks,)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))  # Assuming 7 classes

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Data splitting (you may need to adjust this based on your dataset)
from sklearn.model_selection import train_test_split
landmarks_train, landmarks_test, labels_train, labels_test = train_test_split(landmarks, labels, test_size=0.2, random_state=42)

# Train the model
history = model.fit(landmarks_train, labels_train,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(landmarks_test, labels_test))

# Evaluate the model
accuracy = model.evaluate(landmarks_test, labels_test)
print(f'Test Accuracy: {accuracy[1]}')

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss')
plt.xlabel('Epoch')
plt.show()

# %%
# Load landmark data from CSV
df = pd.read_csv('good-bend-cvin-cvout-nohands-rmv.csv')

# Assuming your CSV has columns for coordinates and labels
landmarks = df.drop(columns=['class']).values
labels = df['class'].values

# Convert string labels to integer labels
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# Convert labels to one-hot encoding
labels = tf.keras.utils.to_categorical(labels, num_classes=4)

# Define parameters
num_landmarks = landmarks.shape[1]  # Assuming the number of landmarks is fixed
batch_size = 10
epochs = 50

# Create a model for landmark-based classification
model = models.Sequential()
model.add(layers.Dense(256, activation='relu', input_shape=(num_landmarks,)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))  # Assuming 7 classes

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Data splitting (you may need to adjust this based on your dataset)
from sklearn.model_selection import train_test_split
landmarks_train, landmarks_test, labels_train, labels_test = train_test_split(landmarks, labels, test_size=0.2, random_state=42)

# Train the model
history = model.fit(landmarks_train, labels_train,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(landmarks_test, labels_test))

# Evaluate the model
accuracy = model.evaluate(landmarks_test, labels_test)
print(f'Test Accuracy: {accuracy[1]}')

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss')
plt.xlabel('Epoch')
plt.show()

# %%
# Load landmark data from CSV
df = pd.read_csv('good-bend-cvin-cvout-nohands-rmv.csv')

# Assuming your CSV has columns for coordinates and labels
landmarks = df.drop(columns=['class']).values
labels = df['class'].values

# Convert string labels to integer labels
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# Convert labels to one-hot encoding
labels = tf.keras.utils.to_categorical(labels, num_classes=4)

# Define parameters
num_landmarks = landmarks.shape[1]  # Assuming the number of landmarks is fixed
batch_size = 100
epochs = 50

# Create a model for landmark-based classification
model = models.Sequential()
model.add(layers.Dense(256, activation='relu', input_shape=(num_landmarks,)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))  # Assuming 7 classes

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Data splitting (you may need to adjust this based on your dataset)
from sklearn.model_selection import train_test_split
landmarks_train, landmarks_test, labels_train, labels_test = train_test_split(landmarks, labels, test_size=0.2, random_state=42)

# Train the model
history = model.fit(landmarks_train, labels_train,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(landmarks_test, labels_test))

# Evaluate the model
accuracy = model.evaluate(landmarks_test, labels_test)
print(f'Test Accuracy: {accuracy[1]}')

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss')
plt.xlabel('Epoch')
plt.show()
# Out:
# WARNING:tensorflow:From C:\Users\eddcr\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\eddcr\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\eddcr\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\eddcr\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 47/47 [==============================] - 2s 12ms/step - loss: 0.9569 - accuracy: 0.6935 - val_loss: 0.8294 - val_accuracy: 0.7114
# Epoch 2/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.7860 - accuracy: 0.7364 - val_loss: 0.6916 - val_accuracy: 0.7455
# Epoch 3/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6547 - accuracy: 0.7742 - val_loss: 0.5653 - val_accuracy: 0.8087
# Epoch 4/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5583 - accuracy: 0.8067 - val_loss: 0.4698 - val_accuracy: 0.8232
# Epoch 5/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.4741 - accuracy: 0.8225 - val_loss: 0.4219 - val_accuracy: 0.8557
# Epoch 6/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.4144 - accuracy: 0.8449 - val_loss: 0.3552 - val_accuracy: 0.8813
# Epoch 7/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.3669 - accuracy: 0.8603 - val_loss: 0.2842 - val_accuracy: 0.8915
# Epoch 8/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.3372 - accuracy: 0.8708 - val_loss: 0.2541 - val_accuracy: 0.8984
# Epoch 9/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.3061 - accuracy: 0.8825 - val_loss: 0.2294 - val_accuracy: 0.9180
# Epoch 10/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.3009 - accuracy: 0.8859 - val_loss: 0.2544 - val_accuracy: 0.8847
# Epoch 11/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.2535 - accuracy: 0.9020 - val_loss: 0.1908 - val_accuracy: 0.9462
# Epoch 12/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.2561 - accuracy: 0.9005 - val_loss: 0.1845 - val_accuracy: 0.9607
# Epoch 13/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.2352 - accuracy: 0.9161 - val_loss: 0.1645 - val_accuracy: 0.9513
# Epoch 14/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.2233 - accuracy: 0.9186 - val_loss: 0.1577 - val_accuracy: 0.9530
# Epoch 15/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.2139 - accuracy: 0.9259 - val_loss: 0.1651 - val_accuracy: 0.9479
# Epoch 16/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.2086 - accuracy: 0.9265 - val_loss: 0.1602 - val_accuracy: 0.9360
# Epoch 17/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.2133 - accuracy: 0.9229 - val_loss: 0.2312 - val_accuracy: 0.8933
# Epoch 18/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.2088 - accuracy: 0.9270 - val_loss: 0.1460 - val_accuracy: 0.9539
# Epoch 19/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1985 - accuracy: 0.9325 - val_loss: 0.1461 - val_accuracy: 0.9445
# Epoch 20/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1847 - accuracy: 0.9338 - val_loss: 0.1528 - val_accuracy: 0.9419
# Epoch 21/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1753 - accuracy: 0.9366 - val_loss: 0.1272 - val_accuracy: 0.9599
# Epoch 22/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1691 - accuracy: 0.9423 - val_loss: 0.1060 - val_accuracy: 0.9744
# Epoch 23/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1678 - accuracy: 0.9428 - val_loss: 0.1129 - val_accuracy: 0.9710
# Epoch 24/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1699 - accuracy: 0.9408 - val_loss: 0.1140 - val_accuracy: 0.9650
# Epoch 25/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1823 - accuracy: 0.9357 - val_loss: 0.1239 - val_accuracy: 0.9667
# Epoch 26/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1585 - accuracy: 0.9451 - val_loss: 0.1164 - val_accuracy: 0.9590
# Epoch 27/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1704 - accuracy: 0.9434 - val_loss: 0.0984 - val_accuracy: 0.9693
# Epoch 28/50
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1512 - accuracy: 0.9496 - val_loss: 0.0894 - val_accuracy: 0.9787
# Epoch 29/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1569 - accuracy: 0.9479 - val_loss: 0.0969 - val_accuracy: 0.9769
# Epoch 30/50
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1411 - accuracy: 0.9509 - val_loss: 0.0881 - val_accuracy: 0.9727
# Epoch 31/50
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1389 - accuracy: 0.9545 - val_loss: 0.0927 - val_accuracy: 0.9727
# Epoch 32/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1456 - accuracy: 0.9490 - val_loss: 0.0929 - val_accuracy: 0.9752
# Epoch 33/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1341 - accuracy: 0.9524 - val_loss: 0.0868 - val_accuracy: 0.9769
# Epoch 34/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1446 - accuracy: 0.9485 - val_loss: 0.0784 - val_accuracy: 0.9795
# Epoch 35/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1333 - accuracy: 0.9545 - val_loss: 0.0810 - val_accuracy: 0.9795
# Epoch 36/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1440 - accuracy: 0.9490 - val_loss: 0.0872 - val_accuracy: 0.9744
# Epoch 37/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1237 - accuracy: 0.9571 - val_loss: 0.0948 - val_accuracy: 0.9658
# Epoch 38/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1323 - accuracy: 0.9530 - val_loss: 0.1204 - val_accuracy: 0.9582
# Epoch 39/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1427 - accuracy: 0.9485 - val_loss: 0.0769 - val_accuracy: 0.9769
# Epoch 40/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1365 - accuracy: 0.9483 - val_loss: 0.0805 - val_accuracy: 0.9761
# Epoch 41/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1285 - accuracy: 0.9554 - val_loss: 0.0798 - val_accuracy: 0.9727
# Epoch 42/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1283 - accuracy: 0.9554 - val_loss: 0.1062 - val_accuracy: 0.9607
# Epoch 43/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1305 - accuracy: 0.9547 - val_loss: 0.0733 - val_accuracy: 0.9761
# Epoch 44/50
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1224 - accuracy: 0.9571 - val_loss: 0.0702 - val_accuracy: 0.9769
# Epoch 45/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1298 - accuracy: 0.9526 - val_loss: 0.0933 - val_accuracy: 0.9624
# Epoch 46/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1259 - accuracy: 0.9577 - val_loss: 0.0745 - val_accuracy: 0.9778
# Epoch 47/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1217 - accuracy: 0.9596 - val_loss: 0.0805 - val_accuracy: 0.9701
# Epoch 48/50
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1301 - accuracy: 0.9545 - val_loss: 0.0755 - val_accuracy: 0.9769
# Epoch 49/50
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1270 - accuracy: 0.9543 - val_loss: 0.0703 - val_accuracy: 0.9795
# Epoch 50/50
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1237 - accuracy: 0.9577 - val_loss: 0.0871 - val_accuracy: 0.9744
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0871 - accuracy: 0.9744
# Test Accuracy: 0.9743808507919312

# %%
model.save('good-bend-cvin-cvout.keras')
